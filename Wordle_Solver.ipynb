# %% [markdown]
# #This is a World Game Solver Program
# Run each cell as needed to solve your game...
#
# This first cell downloads the word list, defines the functions, loads the dictionary, and removes words outside of the focus.

# %% [markdown]
# #After setup, start the program...
# ##(just run the next cell and follow the directions below)

# %%
## You'll need a dictionary. Here are two publicly available word lists.
# These free word lists are incomplete. Not all puzzle words are represented.

#download the U Michigan Word List (~65k words)
dictionlist = "https://www-personal.umich.edu/~jlawler/wordlist"
#download the english sowpods referenced list (~145k words)
dictionlist = "https://www.wordgamedictionary.com/english-word-list/download/english.txt"

# If you want to ensure you most of the words from the NYT Games, I suggest the
# RIDYHEW wordlist available here (zip): https://codehappy.net/wordlist/ridyhew.zip
# RIDYHEW homepage and documentation is here: https://codehappy.net/wordlist.htm
# You'll need to download the wordlist, place it somewhere online, and then reference it...


def checker(ff,gg):
    nn = []
    tt = []
    for i in elist:
        p=0
        for l in i:
            if l not in ff:
                p +=1
        if p ==5:
            nn.append(i)
    #now run the list through the charcount function
    for i in nn:
        if len(gg) > 0:
            pp = 0
            for l in gg:
                if l in i:
                    pp += 1
            if pp < len(gg):
                tt.append(i)
    for i in tt:
        nn.remove(i)
    print(clooker(nn))
    return nn


def clooker(list):
    looks = {'a':0,'b':0,'c':0,'d':0,'e':0,'f':0,'g':0,'h':0,'i':0,'j':0,'k':0,'l':0,'m':0,'n':0,'o':0,'p':0,'q':0,'r':0,'s':0,'t':0,'u':0,'v':0,'w':0,'x':0,'y':0,'z':0}
    for i in list:
        for l in i:
            looks.setdefault(l,0)
            looks[l] += 1
    print('These are the letters and corresponding word prevalence left in the alphabet.')
    dl = sorted([(v ,  k) for k , v in looks.items()], reverse = True)
    return dl

import urllib.request
import math
from pprint import pprint
blist = []
list = []


response = urllib.request.urlopen(dictionlist)

print(f'If the document downloaded correctly you get a 200 message: {response.code}')

for bline in response:
# read each line of the doc into list['word']
#   line.decode(encoding)
    stripped = (bline.rstrip())
    blist.append(stripped.decode())
total_words = len(blist)
print(f'There are {total_words} loaded into the system.')
print('Working to remove unnecessary words. (>5 characters, hyphens, roman numerals, numbers, etc.)')

elist = []
for i in blist:
    if i.isalpha():
        if len(i) == 5:
            #if i.islower() :
                elist.append(i.lower())
set = len(elist)
eliminated = (1-(round(set/total_words,2)))*100
print(f'Complete. {set} words remain. Elimated {eliminated}% so far')

# trail: use the best word you've got (will improve over time)
print('Please input "trail" into the Wordle.')
print('(this word has very popular letters that check over half of the possibilities...')

yes = input('Ready to Continue? (Yes or No) ')
ff = []
gg = []
if yes.lower() == 'yes' or yes.lower() == 'y' :
    print(' ')
    while True:
        print('Please input the BAD letters one at a time')
        print('we already know these are bad:' , ff , ')')
        c = str(input('Input a letter (hit enter to stop): '))
        if c == '':
            break
        elif c.isalpha and len(c) == 1:
            ff.append(c)
    print(' ')
    while True:
        print('Please input the GOOD letters one at a time')
        print('we already know these are good:' , gg , ')')
        g = str(input('Input a letter (hit enter to stop):'))
        if g == '':
            break
        elif g.isalpha and len(g) == 1:
            gg.append(g)

    print(' ')
    print('-------------- checks completed successfully --------------')
    ylist = checker(ff,gg)
    print(f'We\'re down to {len(ylist)} words out of {total_words}.')
    print('Try one of these words next. ')
    pset = math.ceil(len(ylist)/10)
    for i in range(pset):
        st = i*10
        stop = i*10+10
        print(ylist[st:stop])
    print("Tip: Try to pick one with the most popular letters above...")
# Out:
# If the document downloaded correctly you get a 200 message: 200
# There are 144884 loaded into the system.
# Working to remove unnecessary words. (>5 characters, hyphens, roman numerals, numbers, etc.)
# Complete. 5283 words remain. Elimated 96.0% so far
# Please input "trail" into the Wordle.
# (this word has very popular letters that check over half of the possibilities...
# Ready to Continue? (Yes or No) yes
#
# Please input the BAD letters one at a time
# we already know these are bad: [] )
# Input a letter (hit enter to stop): t
# Please input the BAD letters one at a time
# we already know these are bad: ['t'] )
# Input a letter (hit enter to stop): r
# Please input the BAD letters one at a time
# we already know these are bad: ['t', 'r'] )
# Input a letter (hit enter to stop): l
# Please input the BAD letters one at a time
# we already know these are bad: ['t', 'r', 'l'] )
# Input a letter (hit enter to stop):
#
# Please input the GOOD letters one at a time
# we already know these are good: [] )
# Input a letter (hit enter to stop):a
# Please input the GOOD letters one at a time
# we already know these are good: ['a'] )
# Input a letter (hit enter to stop):i
# Please input the GOOD letters one at a time
# we already know these are good: ['a', 'i'] )
# Input a letter (hit enter to stop):n
# Please input the GOOD letters one at a time
# we already know these are good: ['a', 'i', 'n'] )
# Input a letter (hit enter to stop):
#
# -------------- checks completed successfully --------------
# These are the letters and corresponding word prevalence left in the alphabet.
# [(94, 'a'), (90, 'n'), (88, 'i'), (20, 'm'), (19, 's'), (12, 'o'), (12, 'c'), (11, 'g'), (11, 'd'), (9, 'v'), (8, 'h'), (8, 'e'), (7, 'p'), (6, 'k'), (5, 'w'), (5, 'b'), (4, 'u'), (3, 'j'), (2, 'z'), (2, 'q'), (2, 'f'), (1, 'y'), (1, 'x'), (0, 't'), (0, 'r'), (0, 'l')]
# We're down to 84 words out of 144884.
# Try one of these words next.
# ['again', 'aging', 'aiken', 'amain', 'amine', 'amino', 'amnic', 'amnio', 'anima', 'anime']
# ['anion', 'anise', 'anzio', 'apian', 'asian', 'auxin', 'avian', 'awing', 'basin', 'cabin']
# ['canid', 'canis', 'chain', 'chian', 'china', 'diana', 'dinka', 'divan', 'diwan', 'fagin']
# ['gamin', 'hanoi', 'hsian', 'ianfu', 'inane', 'incan', 'india', 'ionia', 'iowan', 'jinja']
# ['kiang', 'kinda', 'maine', 'makin', 'mania', 'manic', 'manis', 'mansi', 'mavin', 'minah']
# ['naiad', 'naias', 'naiki', 'naive', 'namoi', 'naomi', 'nicad', 'nigga', 'nihau', 'ninja']
# ['niqab', 'nisan', 'nomia', 'nsaid', 'nubia', 'omani', 'paine', 'pains', 'panic', 'piano']
# ['pinna', 'qiang', 'sabin', 'savin', 'shina', 'sinai', 'sivan', 'siwan', 'spain', 'swain']
# ['viand', 'vigna', 'vinca', 'zayin']
# Tip: Try to pick one with the most popular letters above...

# %% [markdown]
# # Enter the word you've chosen into Wordle, then come back
# ##(and run the next cell)

# %%
yes = input('Ready to Continue? (Yes or No) ')
if yes.lower() == 'yes' or yes.lower() == 'y' :
    print("Round 2:")
    print(' ')
    while True:
        print('Please input the BAD found letters one at a time')
        print('(we already know these are bad:' , ff ,')')
        c = str(input('Input a letter (hit enter to stop): '))
        if c == '':
            break
        elif c.isalpha and len(c) == 1:
            ff.append(c)
    print(' ')
    while True:
        print('Please input the GOOD letters one at a time')
        print('(we already know these are good:' , gg , ')')
        g = str(input('Input a letter (hit enter to stop): '))
        if g == '':
            break
        elif g.isalpha and len(g) == 1:
            gg.append(g)


    print(' ')
    print('-------------- checks completed successfully --------------')
    ylist = checker(ff,gg)
    print(f'We\'re down to {len(ylist)} words out of {total_words}.')
    print('Try one of these words next. ')
    pset = math.ceil(len(ylist)/10)
    for i in range(pset):
        st = i*10
        stop = i*10+10
        print(ylist[st:stop])
    print("Tip: Try to pick one with the most popular letters above...")
else:
    print("Have a nice day :)")
# Out:
# Ready to Continue? (Yes or No) yes
# Round 2:
#
# Please input the BAD found letters one at a time
# (we already know these are bad: ['t', 'r', 'l'] )
# Input a letter (hit enter to stop): e
# Please input the BAD found letters one at a time
# (we already know these are bad: ['t', 'r', 'l', 'e'] )
# Input a letter (hit enter to stop): a
# Please input the BAD found letters one at a time
# (we already know these are bad: ['t', 'r', 'l', 'e', 'a'] )
# Input a letter (hit enter to stop): y
# Please input the BAD found letters one at a time
# (we already know these are bad: ['t', 'r', 'l', 'e', 'a', 'y'] )
# Input a letter (hit enter to stop):
#
# Please input the GOOD letters one at a time
# (we already know these are good: ['a', 'i', 'n'] )
# Input a letter (hit enter to stop): m
# Please input the GOOD letters one at a time
# (we already know these are good: ['a', 'i', 'n', 'm'] )
# Input a letter (hit enter to stop): s
# Please input the GOOD letters one at a time
# (we already know these are good: ['a', 'i', 'n', 'm', 's'] )
# Input a letter (hit enter to stop):
#
# -------------- checks completed successfully --------------
# These are the letters and corresponding word prevalence left in the alphabet.
# [(0, 'z'), (0, 'y'), (0, 'x'), (0, 'w'), (0, 'v'), (0, 'u'), (0, 't'), (0, 's'), (0, 'r'), (0, 'q'), (0, 'p'), (0, 'o'), (0, 'n'), (0, 'm'), (0, 'l'), (0, 'k'), (0, 'j'), (0, 'i'), (0, 'h'), (0, 'g'), (0, 'f'), (0, 'e'), (0, 'd'), (0, 'c'), (0, 'b'), (0, 'a')]
# We're down to 0 words out of 144884.
# Try one of these words next.
# Tip: Try to pick one with the most popular letters above...

# %% [markdown]
# #Round 3: Input the word you've chosen from above into Wordle.
# ##(Then come back and run the next cell)

# %%
yes = input('Ready to Continue? (Yes or No) ')
if yes.lower() == 'yes' or yes.lower() == 'y' :
    print("Round 3:")
    print(' ')
    while True:
        print('Please input the BAD found letters one at a time')
        print('(we already know these are bad:' , ff ,')')
        c = str(input('Input a letter (hit enter to stop): '))
        if c == '':
            break
        elif c.isalpha and len(c) == 1:
            ff.append(c)
    print(' ')
    while True:
        print('Please input the GOOD letters one at a time')
        print('(we already know these are good:' , gg , ')')
        g = str(input('Input a letter (hit enter to stop): '))
        if g == '':
            break
        elif g.isalpha and len(g) == 1:
            gg.append(g)


    print(' ')
    print('-------------- checks completed successfully --------------')
    ylist = checker(ff,gg)
    print(f'We\'re down to {len(ylist)} words out of {total_words}.')
    print('Try another word, with the most popular letters above...')
    pset = math.ceil(len(ylist)/10)
    for i in range(pset):
        st = i*10
        stop = i*10+10
        print(ylist[st:stop])
    print("Pick a word. OR have me line up your green letters.")
else:
    print("Have a nice day :)")
# Out:
# Ready to Continue? (Yes or No) y
# Round 3:
#
# Please input the BAD found letters one at a time
# (we already know these are bad: ['t', 'r', 'a', 'i', 's', 'w', 'e'] )
# Input a letter (hit enter to stop): d
# Please input the BAD found letters one at a time
# (we already know these are bad: ['t', 'r', 'a', 'i', 's', 'w', 'e', 'd'] )
# Input a letter (hit enter to stop):
#
# Please input the GOOD letters one at a time
# (we already know these are good: ['l', 'o'] )
# Input a letter (hit enter to stop): y
# Please input the GOOD letters one at a time
# (we already know these are good: ['l', 'o', 'y'] )
# Input a letter (hit enter to stop):
#
# -------------- checks completed successfully --------------
# These are the letters and corresponding word prevalence left in the alphabet.
# [(26, 'l'), (23, 'o'), (19, 'y'), (5, 'n'), (4, 'p'), (4, 'c'), (3, 'b'), (1, 'x'), (1, 'm'), (1, 'j'), (1, 'h'), (1, 'g'), (1, 'f'), (0, 'z'), (0, 'w'), (0, 'v'), (0, 'u'), (0, 't'), (0, 's'), (0, 'r'), (0, 'q'), (0, 'k'), (0, 'i'), (0, 'e'), (0, 'd'), (0, 'a')]
# We're down to 18 words out of 144884.
# Try another word, with the most popular letters above...
# ['colly', 'cooly', 'coyly', 'coyol', 'folly', 'holly', 'jolly', 'lobby', 'lolly', 'loony']
# ['loopy', 'molly', 'nobly', 'nylon', 'ology', 'polyp', 'pylon', 'xylol']
# Pick a word. OR have me line up your green letters.

# %% [markdown]
# #Round 4: You're running out of chances to win this wordle...
# This round will use the same format. Good Luck!!!

# %%
 print("Round 4:")
yes = input('Continue? (Yes or No) ')
if yes.lower() == 'yes' or yes.lower() == 'y' :
    while True:
        print('Please input the BAD found letters one at a time')
        print('(we already know these are bad:' , ff ,')')
        c = str(input('Input a letter (hit enter to stop): '))
        if c == '':
            break
        elif c.isalpha and len(c) == 1:
            ff.append(c)
    print(' ')
    while True:
        print('Please input the GOOD letters one at a time')
        print('(we already know these are good:' , gg , ')')
        g = str(input('Input a letter (hit enter to stop): '))
        if g == '':
            break
        elif g.isalpha and len(g) == 1:
            gg.append(g)


    print(' ')
    print('-------------- checks completed successfully --------------')
    ylist = checker(ff,gg)
    print(f'We\'re down to {len(ylist)} words out of {total_words}.')
    print('Try another word, with the most popular letters above...')
    pset = math.ceil(len(ylist)/10)
    for i in range(pset):
        st = i*10
        stop = i*10+10
        print(ylist[st:stop])
    print("We have to pick a word from these. Let's ensure we've lined up your green letters.")


else:
    print("Have a nice day :)")
# Out:
# 3496

# %% [markdown]
# # Distraction Before the Debugging and Helper Functions...
# The below sections show some of the math and thought that went into the program you have used above. This pretty fractal is here because I liked it.
#
# Feel free to peruse the logic.

# %%
## IMHO, math and coding is really pretty when done well.
## Run the math in this cell 1st
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

w, h, zoom = 1000 ,500,2
pix = np.zeros((h,w)) # Array filled with zeros

# setting up the variables according to the equation to create the fractal
cX, cY = -0.7, 0.27015
moveX, moveY = 0.0, 0.0
maxIter = 255

for x in range(w):
  for y in range(h):
     zx = 1.5*(x - w/2)/(0.57*zoom*w) + moveX
     zy = 1.0*(y - h/2)/(0.57*zoom*h) + moveY
     i = maxIter
     while zx*zx + zy*zy < 4 and i > 1:
       tmp = zx*zx - zy*zy + cX
       zy,zx = 2.0*zx*zy + cY, tmp
       i -= 1

     pix[y,x] = i


# Plotting in new cell, so we do not need to recalculate when chaning color maps
plt.rcParams['figure.figsize'] = [20, 10]
plt.axis('off')
plt.imshow(pix, cmap="magma_r")
#plt.imshow(pix, cmap="twilight")
#plt.imshow(pix, cmap="afmhot")

# %% [markdown]
# # How did we arrive at "Trail" as the first word?
# This allows you to check your first word against the loaded dictionary...

# %%
errcheck = []
c = 0
checks = ['s','l','a','i','n']
for i in elist:
    for l in i:
        if l in checks:
            c +=1
            errcheck.append(i)
            break
print(checks, ' covers ', len(errcheck) , ' words')

errcheck = []
c = 0
checks = ['t','r','a','i','l']
for i in elist:
    for l in i:
        if l in checks:
            c +=1
            errcheck.append(i)
            break

print(checks, ' covers ', len(errcheck) , ' words')
# Out:
# ['s', 'l', 'a', 'i', 'n']  covers  3496  words
# ['t', 'r', 'a', 'i', 'l']  covers  3597  words

# %%
# How Many Words from the Loaded Dictionary have any 2 Letters?

You are welcome to check how many words contain a list of letters with the following function.

# %%
errcheck = []
c = 0
checks = ['e','i']
for i in elist:
    c=0
    for l in checks:
        if l in i:
            c += 1
    if c >= 2:
        errcheck.append(i)
print(f'There are {len(errcheck)} words that meet the criteria:')
for i in range(math.ceil(len(errcheck)/10)):
    st = i * 10
    sto = st +10
    print(errcheck[st:sto])
# Out:
# There are 403 words that meet the criteria:
# ['abide', 'adieu', 'aegir', 'aegis', 'aerie', 'agile', 'aided', 'aired', 'aisle', 'alien']
# ['alike', 'aline', 'alive', 'amide', 'amine', 'anile', 'anime', 'anise', 'arise', 'aside']
# ['axile', 'azide', 'baize', 'bedim', 'befit', 'beige', 'being', 'belie', 'benni', 'bible']
# ['bidet', 'bilge', 'binge', 'biome', 'biped', 'birle', 'biter', 'bogie', 'bosie', 'bribe']
# ['bride', 'brief', 'brier', 'brine', 'ceibo', 'ceric', 'chide', 'chief', 'chile', 'chime']
# ['chine', 'chive', 'cider', 'civet', 'clime', 'cozie', 'crier', 'crime', 'debit', 'deice']
# ['deify', 'deign', 'deism', 'deist', 'deity', 'denim', 'devil', 'dicer', 'dicey', 'dimer']
# ['diner', 'dinge', 'diode', 'dirge', 'diver', 'dixie', 'dizen', 'dogie', 'dried', 'drier']
# ['drive', 'eblis', 'edict', 'edify', 'eerie', 'eider', 'eidos', 'elemi', 'elfin', 'elide']
# ['elite', 'email', 'ennui', 'envoi', 'eosin', 'equid', 'equip', 'erica', 'ethic', 'evict']
# ['exile', 'exist', 'eyrie', 'eyrir', 'feign', 'feint', 'feist', 'felid', 'feria', 'fetid']
# ['fiber', 'fibre', 'field', 'fiend', 'fiery', 'filer', 'filet', 'fille', 'fined', 'finer']
# ['fired', 'fiver', 'fives', 'fixed', 'fixer', 'flier', 'flies', 'folie', 'fried', 'frier']
# ['fries', 'gelid', 'genic', 'genie', 'genip', 'gimel', 'ginep', 'given', 'giver', 'glide']
# ['grief', 'grime', 'gripe', 'guide', 'guile', 'guise', 'heist', 'hemic', 'hemin', 'hiker']
# ['hinge', 'hired', 'hirer', 'hives', 'hymie', 'ideal', 'idler', 'ileum', 'ileus', 'image']
# ['imbed', 'imbue', 'imide', 'impel', 'inane', 'index', 'indie', 'indue', 'inept', 'inert']
# ['infer', 'inkle', 'inlet', 'inner', 'inset', 'inter', 'inure', 'irate', 'islet', 'issue']
# ['ivied', 'juice', 'kiley', 'knife', 'koine', 'kylie', 'legin', 'levis', 'lexis', 'libel']
# ['lifer', 'liger', 'ligne', 'liked', 'liken', 'limen', 'limey', 'lined', 'linen', 'liner']
# ['lisle', 'liter', 'lithe', 'litre', 'liven', 'liver', 'maize', 'medic', 'merit', 'mesic']
# ['metic', 'metis', 'midge', 'miler', 'mimeo', 'mimer', 'mince', 'mined', 'miner', 'minge']
# ['mired', 'miser', 'miter', 'mitre', 'mixed', 'mixer', 'mizen', 'moire', 'movie', 'moxie']
# ['naive', 'neigh', 'niche', 'niece', 'niner', 'niter', 'nitre', 'noise', 'ogive', 'oiled']
# ['oiler', 'oldie', 'olein', 'olive', 'opine', 'oriel', 'osier', 'ovine', 'oxide', 'oxime']
# ['penis', 'penni', 'peril', 'pewit', 'piece', 'pieta', 'piety', 'piled', 'piles', 'piper']
# ['pipes', 'pipet', 'pique', 'piste', 'pixel', 'pixie', 'plier', 'poise', 'price', 'pride']
# ['prime', 'prise', 'prize', 'pyxie', 'qepiq', 'quiet', 'quire', 'quite', 'raise', 'ramie']
# ['refit', 'reify', 'reign', 'reins', 'rejig', 'relic', 'remit', 'renin', 'resid', 'resin']
# ['retie', 'ricer', 'rider', 'ridge', 'rifle', 'riled', 'rimed', 'rinse', 'ripen', 'risen']
# ['riser', 'river', 'rivet', 'seine', 'seism', 'seize', 'serif', 'serin', 'sheik', 'shine']
# ['shire', 'shite', 'sidle', 'siege', 'sieve', 'sigeh', 'sinew', 'singe', 'siren', 'sixer']
# ['sized', 'skein', 'skier', 'skive', 'slice', 'slide', 'slime', 'smile', 'smite', 'snide']
# ['snipe', 'spice', 'spiel', 'spike', 'spile', 'spine', 'spire', 'spite', 'stein', 'stile']
# ['stipe', 'suite', 'swine', 'swipe', 'teiid', 'tekki', 'tenia', 'tepid', 'tetri', 'thief']
# ['tiger', 'tilde', 'tiled', 'tiler', 'timed', 'timer', 'times', 'tined', 'tinge', 'tired']
# ['titer', 'tithe', 'title', 'titre', 'tribe', 'trice', 'tried', 'trier', 'trike', 'trine']
# ['tripe', 'trite', 'tsine', 'twice', 'twine', 'unite', 'untie', 'urine', 'utile', 'vibes']
# ['video', 'viper', 'vireo', 'vixen', 'voice', 'voile', 'waive', 'weigh', 'while', 'whine']
# ['white', 'widen', 'wield', 'wince', 'winey', 'wiper', 'wired', 'wirer', 'withe', 'wizen']
# ['write', 'xeric', 'yield']
